# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from model import *
from data_utils import *
from visualization import *
from data_preprocessing import *
from heatwave_predict import *

# load and preprocess data
df = preprocess_data('../Dataset/Bengaluru.csv')

# scale data
scaler, scaled = scale_data(df)

# split data into train and test sets
train, test = split_train_test(scaled)

# prepare data for LSTM model
n_steps_in = 7
n_steps_out = 1
trainX, trainY = prepare_data(train, n_steps_in, n_steps_out)
testX, testY = prepare_data(test, n_steps_in, n_steps_out)

# define and fit the LSTM model
model = build_model(trainX, n_steps_in, n_steps_out)
history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), verbose=2)

# make predictions and evaluate the model
rmseScore, maeScore, predictTemp, realTemp = evaluate_model(model, scaler, testX, testY)
rmseScore_, maeScore_, predictTemp_, realTemp_ = evaluate_model(model, scaler, trainX, trainY)
print('Train Score: %.2f RMSE' % (rmseScore))
print('Test Score: %.2f MAE' % (maeScore))

# plot the predicted and actual temperatures
date = df.tail(realTemp.shape[0]).index
plot_train_test_predictions(realTemp, predictTemp, date)
plot_loss(history)

# predict the heatwave
occurredHeatwave, predictedHeatwave, accuracy = predict_heatwave(predictTemp, realTemp, realTemp_, df)
print("Occurred Heatwaves between 2012 & 2022 -> ", occurredHeatwave)
print("Predicted Heatwaves between 2012 & 2022 -> ", predictedHeatwave)
print(f"Heatwave Prediction accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/30
# 361/361 - 15s - loss: 0.0542 - val_loss: 0.0046 - 15s/epoch - 41ms/step
# Epoch 2/30
# 361/361 - 5s - loss: 0.0063 - val_loss: 0.0016 - 5s/epoch - 15ms/step
# Epoch 3/30
# 361/361 - 5s - loss: 0.0056 - val_loss: 0.0015 - 5s/epoch - 15ms/step
# Epoch 4/30
# 361/361 - 5s - loss: 0.0049 - val_loss: 6.9997e-04 - 5s/epoch - 15ms/step
# Epoch 5/30
# 361/361 - 6s - loss: 0.0046 - val_loss: 4.4719e-04 - 6s/epoch - 18ms/step
# Epoch 6/30
# 361/361 - 7s - loss: 0.0044 - val_loss: 3.5162e-04 - 7s/epoch - 19ms/step
# Epoch 7/30
# 361/361 - 7s - loss: 0.0044 - val_loss: 7.2091e-04 - 7s/epoch - 21ms/step
# Epoch 8/30
# 361/361 - 5s - loss: 0.0038 - val_loss: 7.3194e-04 - 5s/epoch - 15ms/step
# Epoch 9/30
# 361/361 - 5s - loss: 0.0041 - val_loss: 8.5302e-04 - 5s/epoch - 15ms/step
# Epoch 10/30
# 361/361 - 5s - loss: 0.0035 - val_loss: 0.0020 - 5s/epoch - 14ms/step
# Epoch 11/30
# 361/361 - 5s - loss: 0.0032 - val_loss: 7.8595e-04 - 5s/epoch - 13ms/step
# Epoch 12/30
# 361/361 - 5s - loss: 0.0031 - val_loss: 3.5370e-04 - 5s/epoch - 14ms/step
# Epoch 13/30
# 361/361 - 5s - loss: 0.0030 - val_loss: 4.3471e-04 - 5s/epoch - 13ms/step
# Epoch 14/30
# 361/361 - 3s - loss: 0.0031 - val_loss: 5.6729e-04 - 3s/epoch - 8ms/step
# Epoch 15/30
# 361/361 - 4s - loss: 0.0030 - val_loss: 0.0012 - 4s/epoch - 11ms/step
# Epoch 16/30
# 361/361 - 3s - loss: 0.0025 - val_loss: 2.1581e-04 - 3s/epoch - 9ms/step
# Epoch 17/30
# 361/361 - 3s - loss: 0.0026 - val_loss: 5.4847e-04 - 3s/epoch - 8ms/step
# Epoch 18/30
# 361/361 - 3s - loss: 0.0026 - val_loss: 8.5157e-04 - 3s/epoch - 9ms/step
# Epoch 19/30
# 361/361 - 4s - loss: 0.0025 - val_loss: 6.3926e-04 - 4s/epoch - 10ms/step
# Epoch 20/30
# 361/361 - 4s - loss: 0.0024 - val_loss: 5.8298e-04 - 4s/epoch - 11ms/step
# Epoch 21/30
# 361/361 - 3s - loss: 0.0025 - val_loss: 1.9712e-04 - 3s/epoch - 10ms/step
# Epoch 22/30
# 361/361 - 3s - loss: 0.0021 - val_loss: 4.2924e-04 - 3s/epoch - 9ms/step
# Epoch 23/30
# 361/361 - 3s - loss: 0.0022 - val_loss: 4.0500e-04 - 3s/epoch - 9ms/step
# Epoch 24/30
# 361/361 - 4s - loss: 0.0021 - val_loss: 3.3877e-04 - 4s/epoch - 11ms/step
# Epoch 25/30
# 361/361 - 4s - loss: 0.0019 - val_loss: 3.3246e-04 - 4s/epoch - 11ms/step
# Epoch 26/30
# 361/361 - 3s - loss: 0.0019 - val_loss: 3.5910e-04 - 3s/epoch - 10ms/step
# Epoch 27/30
# 361/361 - 4s - loss: 0.0019 - val_loss: 3.5950e-04 - 4s/epoch - 11ms/step
# Epoch 28/30
# 361/361 - 4s - loss: 0.0019 - val_loss: 3.0890e-04 - 4s/epoch - 11ms/step
# Epoch 29/30
# 361/361 - 4s - loss: 0.0018 - val_loss: 6.6010e-04 - 4s/epoch - 11ms/step
# Epoch 30/30
# 361/361 - 6s - loss: 0.0016 - val_loss: 7.5654e-04 - 6s/epoch - 16ms/step
# 121/121 [==============================] - 2s 5ms/step
# 361/361 [==============================] - 2s 6ms/step
# Train Score: 0.10 RMSE
# Test Score: 0.07 MAE
# Occurred Heatwaves between 2012 & 2022 ->  105
# Predicted Heatwaves between 2012 & 2022 ->  105
# Heatwave Prediction accuracy: 100.00%
