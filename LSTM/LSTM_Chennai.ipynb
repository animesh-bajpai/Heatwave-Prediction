# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from model import *
from data_utils import *
from visualization import *
from data_preprocessing import *
from heatwave_predict import *

# load and preprocess data
df = preprocess_data('../Dataset/Chennai.csv')

# scale data
scaler, scaled = scale_data(df)

# split data into train and test sets
train, test = split_train_test(scaled)

# prepare data for LSTM model
n_steps_in = 7
n_steps_out = 1
trainX, trainY = prepare_data(train, n_steps_in, n_steps_out)
testX, testY = prepare_data(test, n_steps_in, n_steps_out)

# define and fit the LSTM model
model = build_model(trainX, n_steps_in, n_steps_out)
history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), verbose=2)

# make predictions and evaluate the model
rmseScore, maeScore, predictTemp, realTemp = evaluate_model(model, scaler, testX, testY)
rmseScore_, maeScore_, predictTemp_, realTemp_ = evaluate_model(model, scaler, trainX, trainY)
print('Train Score: %.2f RMSE' % (rmseScore))
print('Test Score: %.2f MAE' % (maeScore))

# plot the predicted and actual temperatures
date = df.tail(realTemp.shape[0]).index
plot_train_test_predictions(realTemp, predictTemp, date)
plot_loss(history)

# predict the heatwave
occurredHeatwave, predictedHeatwave, accuracy = predict_heatwave(predictTemp, realTemp, realTemp_, df)
print("Occurred Heatwaves between 2012 & 2022 -> ", occurredHeatwave)
print("Predicted Heatwaves between 2012 & 2022 -> ", predictedHeatwave)
print(f"Heatwave Prediction accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/30
# 361/361 - 16s - loss: 0.0460 - val_loss: 0.0032 - 16s/epoch - 44ms/step
# Epoch 2/30
# 361/361 - 6s - loss: 0.0061 - val_loss: 0.0011 - 6s/epoch - 16ms/step
# Epoch 3/30
# 361/361 - 6s - loss: 0.0047 - val_loss: 0.0020 - 6s/epoch - 16ms/step
# Epoch 4/30
# 361/361 - 6s - loss: 0.0046 - val_loss: 0.0013 - 6s/epoch - 15ms/step
# Epoch 5/30
# 361/361 - 7s - loss: 0.0042 - val_loss: 3.3590e-04 - 7s/epoch - 18ms/step
# Epoch 6/30
# 361/361 - 7s - loss: 0.0042 - val_loss: 5.5235e-04 - 7s/epoch - 19ms/step
# Epoch 7/30
# 361/361 - 6s - loss: 0.0038 - val_loss: 0.0017 - 6s/epoch - 16ms/step
# Epoch 8/30
# 361/361 - 6s - loss: 0.0039 - val_loss: 0.0012 - 6s/epoch - 16ms/step
# Epoch 9/30
# 361/361 - 6s - loss: 0.0037 - val_loss: 7.9962e-04 - 6s/epoch - 16ms/step
# Epoch 10/30
# 361/361 - 7s - loss: 0.0033 - val_loss: 3.4346e-04 - 7s/epoch - 18ms/step
# Epoch 11/30
# 361/361 - 6s - loss: 0.0035 - val_loss: 0.0020 - 6s/epoch - 16ms/step
# Epoch 12/30
# 361/361 - 6s - loss: 0.0035 - val_loss: 0.0019 - 6s/epoch - 17ms/step
# Epoch 13/30
# 361/361 - 6s - loss: 0.0032 - val_loss: 0.0022 - 6s/epoch - 16ms/step
# Epoch 14/30
# 361/361 - 4s - loss: 0.0031 - val_loss: 4.7332e-04 - 4s/epoch - 12ms/step
# Epoch 15/30
# 361/361 - 6s - loss: 0.0032 - val_loss: 0.0017 - 6s/epoch - 16ms/step
# Epoch 16/30
# 361/361 - 6s - loss: 0.0031 - val_loss: 4.8546e-04 - 6s/epoch - 15ms/step
# Epoch 17/30
# 361/361 - 6s - loss: 0.0030 - val_loss: 7.2616e-04 - 6s/epoch - 16ms/step
# Epoch 18/30
# 361/361 - 6s - loss: 0.0031 - val_loss: 6.2296e-04 - 6s/epoch - 16ms/step
# Epoch 19/30
# 361/361 - 7s - loss: 0.0025 - val_loss: 5.3893e-04 - 7s/epoch - 18ms/step
# Epoch 20/30
# 361/361 - 7s - loss: 0.0027 - val_loss: 6.0191e-04 - 7s/epoch - 18ms/step
# Epoch 21/30
# 361/361 - 6s - loss: 0.0025 - val_loss: 3.6343e-04 - 6s/epoch - 17ms/step
# Epoch 22/30
# 361/361 - 6s - loss: 0.0024 - val_loss: 4.5245e-04 - 6s/epoch - 17ms/step
# Epoch 23/30
# 361/361 - 6s - loss: 0.0022 - val_loss: 4.9212e-04 - 6s/epoch - 18ms/step
# Epoch 24/30
# 361/361 - 7s - loss: 0.0022 - val_loss: 3.2106e-04 - 7s/epoch - 18ms/step
# Epoch 25/30
# 361/361 - 7s - loss: 0.0020 - val_loss: 3.8877e-04 - 7s/epoch - 19ms/step
# Epoch 26/30
# 361/361 - 6s - loss: 0.0021 - val_loss: 4.6815e-04 - 6s/epoch - 18ms/step
# Epoch 27/30
# 361/361 - 6s - loss: 0.0019 - val_loss: 2.9933e-04 - 6s/epoch - 18ms/step
# Epoch 28/30
# 361/361 - 6s - loss: 0.0018 - val_loss: 0.0011 - 6s/epoch - 16ms/step
# Epoch 29/30
# 361/361 - 6s - loss: 0.0019 - val_loss: 2.8445e-04 - 6s/epoch - 16ms/step
# Epoch 30/30
# 361/361 - 6s - loss: 0.0018 - val_loss: 9.3218e-04 - 6s/epoch - 17ms/step
# 121/121 [==============================] - 2s 7ms/step
# 361/361 [==============================] - 3s 7ms/step
# Train Score: 0.11 RMSE
# Test Score: 0.09 MAE
# Occurred Heatwaves between 2012 & 2022 ->  95
# Predicted Heatwaves between 2012 & 2022 ->  104
# Heatwave Prediction accuracy: 99.71%
