# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from model import *
from data_utils import *
from visualization import *
from data_preprocessing import *
from heatwave_predict import *

# load and preprocess data
df = preprocess_data('../Dataset/Shillong.csv')

# scale data
scaler, scaled = scale_data(df)

# split data into train and test sets
train, test = split_train_test(scaled)

# prepare data for LSTM model
n_steps_in = 7
n_steps_out = 1
trainX, trainY = prepare_data(train, n_steps_in, n_steps_out)
testX, testY = prepare_data(test, n_steps_in, n_steps_out)

# define and fit the LSTM model
model = build_model(trainX, n_steps_in, n_steps_out)
history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), verbose=2)

# make predictions and evaluate the model
rmseScore, maeScore, predictTemp, realTemp = evaluate_model(model, scaler, testX, testY)
rmseScore_, maeScore_, predictTemp_, realTemp_ = evaluate_model(model, scaler, trainX, trainY)
print('Train Score: %.2f RMSE' % (rmseScore))
print('Test Score: %.2f MAE' % (maeScore))

# plot the predicted and actual temperatures
date = df.tail(realTemp.shape[0]).index
plot_train_test_predictions(realTemp, predictTemp, date)
plot_loss(history)

# predict the heatwave
occurredHeatwave, predictedHeatwave, accuracy = predict_heatwave(predictTemp, realTemp, realTemp_, df)
print("Occurred Heatwaves between 2012 & 2022 -> ", occurredHeatwave)
print("Predicted Heatwaves between 2012 & 2022 -> ", predictedHeatwave)
print(f"Heatwave Prediction accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/30
# 361/361 - 17s - loss: 0.0346 - val_loss: 0.0024 - 17s/epoch - 48ms/step
# Epoch 2/30
# 361/361 - 6s - loss: 0.0050 - val_loss: 9.2834e-04 - 6s/epoch - 17ms/step
# Epoch 3/30
# 361/361 - 6s - loss: 0.0040 - val_loss: 6.1402e-04 - 6s/epoch - 16ms/step
# Epoch 4/30
# 361/361 - 6s - loss: 0.0038 - val_loss: 4.6884e-04 - 6s/epoch - 16ms/step
# Epoch 5/30
# 361/361 - 6s - loss: 0.0033 - val_loss: 5.7758e-04 - 6s/epoch - 17ms/step
# Epoch 6/30
# 361/361 - 6s - loss: 0.0031 - val_loss: 0.0012 - 6s/epoch - 17ms/step
# Epoch 7/30
# 361/361 - 6s - loss: 0.0027 - val_loss: 5.7401e-04 - 6s/epoch - 16ms/step
# Epoch 8/30
# 361/361 - 6s - loss: 0.0025 - val_loss: 6.5480e-04 - 6s/epoch - 16ms/step
# Epoch 9/30
# 361/361 - 6s - loss: 0.0026 - val_loss: 7.1352e-04 - 6s/epoch - 16ms/step
# Epoch 10/30
# 361/361 - 6s - loss: 0.0024 - val_loss: 0.0013 - 6s/epoch - 16ms/step
# Epoch 11/30
# 361/361 - 6s - loss: 0.0022 - val_loss: 5.2343e-04 - 6s/epoch - 17ms/step
# Epoch 12/30
# 361/361 - 6s - loss: 0.0020 - val_loss: 2.9096e-04 - 6s/epoch - 16ms/step
# Epoch 13/30
# 361/361 - 6s - loss: 0.0020 - val_loss: 6.0168e-04 - 6s/epoch - 16ms/step
# Epoch 14/30
# 361/361 - 6s - loss: 0.0019 - val_loss: 4.0691e-04 - 6s/epoch - 16ms/step
# Epoch 15/30
# 361/361 - 6s - loss: 0.0018 - val_loss: 7.4270e-04 - 6s/epoch - 16ms/step
# Epoch 16/30
# 361/361 - 5s - loss: 0.0017 - val_loss: 4.1151e-04 - 5s/epoch - 15ms/step
# Epoch 17/30
# 361/361 - 6s - loss: 0.0017 - val_loss: 0.0010 - 6s/epoch - 16ms/step
# Epoch 18/30
# 361/361 - 6s - loss: 0.0015 - val_loss: 2.3685e-04 - 6s/epoch - 16ms/step
# Epoch 19/30
# 361/361 - 6s - loss: 0.0015 - val_loss: 2.8874e-04 - 6s/epoch - 16ms/step
# Epoch 20/30
# 361/361 - 6s - loss: 0.0015 - val_loss: 2.1352e-04 - 6s/epoch - 16ms/step
# Epoch 21/30
# 361/361 - 6s - loss: 0.0014 - val_loss: 2.9181e-04 - 6s/epoch - 16ms/step
# Epoch 22/30
# 361/361 - 6s - loss: 0.0013 - val_loss: 7.5495e-04 - 6s/epoch - 16ms/step
# Epoch 23/30
# 361/361 - 6s - loss: 0.0014 - val_loss: 2.1822e-04 - 6s/epoch - 16ms/step
# Epoch 24/30
# 361/361 - 6s - loss: 0.0014 - val_loss: 4.7348e-04 - 6s/epoch - 16ms/step
# Epoch 25/30
# 361/361 - 6s - loss: 0.0013 - val_loss: 1.8558e-04 - 6s/epoch - 16ms/step
# Epoch 26/30
# 361/361 - 6s - loss: 0.0012 - val_loss: 1.2571e-04 - 6s/epoch - 16ms/step
# Epoch 27/30
# 361/361 - 6s - loss: 0.0011 - val_loss: 3.5663e-04 - 6s/epoch - 16ms/step
# Epoch 28/30
# 361/361 - 5s - loss: 0.0012 - val_loss: 0.0014 - 5s/epoch - 14ms/step
# Epoch 29/30
# 361/361 - 5s - loss: 0.0011 - val_loss: 1.6108e-04 - 5s/epoch - 14ms/step
# Epoch 30/30
# 361/361 - 4s - loss: 0.0012 - val_loss: 2.2768e-04 - 4s/epoch - 12ms/step
# 121/121 [==============================] - 1s 4ms/step
# 361/361 [==============================] - 1s 4ms/step
# Train Score: 0.05 RMSE
# Test Score: 0.04 MAE
# Occurred Heatwaves between 2012 & 2022 ->  2
# Predicted Heatwaves between 2012 & 2022 ->  2
# Heatwave Prediction accuracy: 100.00%
